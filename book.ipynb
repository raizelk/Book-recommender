# %% [markdown]
# # BOOK RECOMMENDER SYSTEM

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
books = pd.read_csv('books_1.Best_Books_Ever.csv',sep=";", on_bad_lines="skip", encoding='latin-1')

# %%
books = pd.read_csv("books_1.Best_Books_Ever.csv", delimiter=',')

# %%
books.columns
# Out:
# Index(['bookId', 'title', 'series', 'author', 'rating', 'description',
#        'language', 'isbn', 'genres', 'characters', 'bookFormat', 'edition',
#        'pages', 'publisher', 'publishDate', 'firstPublishDate', 'awards',
#        'numRatings', 'ratingsByStars', 'likedPercent', 'setting', 'coverImg',
#        'bbeScore', 'bbeVotes', 'price'],
#       dtype='object')

# %%
books.head(4)
# Out:
#                                         bookId  \
# 0                     2767052-the-hunger-games
# 1  2.Harry_Potter_and_the_Order_of_the_Phoenix
# 2                   2657.To_Kill_a_Mockingbird
# 3                     1885.Pride_and_Prejudice
#
#                                        title                 series  \
# 0                           The Hunger Games    The Hunger Games #1
# 1  Harry Potter and the Order of the Phoenix        Harry Potter #5
# 2                      To Kill a Mockingbird  To Kill a Mockingbird
# 3                        Pride and Prejudice                    NaN
#
#                                       author  rating  \
# 0                            Suzanne Collins    4.33
# 1  J.K. Rowling, Mary GrandPré (Illustrator)    4.50
# 2                                 Harper Lee    4.28
# 3  Jane Austen, Anna Quindlen (Introduction)    4.26
#
#                                          description language           isbn  \
# ...

# %%
books1= pd.read_csv('BX-Books.csv',sep=";",on_bad_lines ="skip", encoding='latin-1' )
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_8444\1637899438.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books1= pd.read_csv('BX-Books.csv',sep=";",on_bad_lines ="skip", encoding='latin-1' )

# %%
books1.head(2)
# Out:
#          ISBN           Book-Title           Book-Author Year-Of-Publication  \
# 0  0195153448  Classical Mythology    Mark P. O. Morford                2002
# 1  0002005018         Clara Callan  Richard Bruce Wright                2001
#
#                  Publisher                                        Image-URL-S  \
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
# 1    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...

# %%
books1.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')

# %%
books1.rename(columns={
    "ISBN": "isbn",
    "Book-Title":"title",
    "Book-Author": "author",
    "Year-Of-Publication":"year",
    "Publisher": "publisher",
    "Image-URL-M": "img"},inplace =True)

# %%
books1.head(4)
# Out:
#          isbn                                              title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
#
#                  author  year                publisher  \
# 0    Mark P. O. Morford  2002  Oxford University Press
# 1  Richard Bruce Wright  2001    HarperFlamingo Canada
# 2          Carlo D'Este  1991          HarperPerennial
# 3      Gina Bari Kolata  1999     Farrar Straus Giroux
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
#
#                                                  img  \
# ...

# %%
users = pd.read_csv('BX-Users.csv',sep=";", on_bad_lines="skip", encoding='latin-1')

# %%
users.head(4)
# Out:
#    User-ID                         Location   Age
# 0        1               nyc, new york, usa   NaN
# 1        2        stockton, california, usa  18.0
# 2        3  moscow, yukon territory, russia   NaN
# 3        4        porto, v.n.gaia, portugal  17.0

# %%
ratings = pd.read_csv('BX-Book-Ratings.csv',sep=";", on_bad_lines="skip", encoding='latin-1')

# %%
ratings.head(4)
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3

# %%
ratings.rename(columns={
    "User-ID": "userid",
    "ISBN": "isbn",
    "Book-Rating": "rating"
},inplace =True)

# %%
ratings.head(4)
# Out:
#    userid        isbn  rating
# 0  276725  034545104X       0
# 1  276726  0155061224       5
# 2  276727  0446520802       0
# 3  276729  052165615X       3

# %%
ratings["userid"].unique().shape
# Out:
# (105283,)

# %%
x= ratings["userid"].value_counts()>200

# %%
x[x].shape
# Out:
# (899,)

# %%
y=x[x].index

# %%
y
# Out:
# Index([ 11676, 198711, 153662,  98391,  35859, 212898, 278418,  76352, 110973,
#        235105,
#        ...
#        260183,  73681,  44296, 155916,   9856, 274808,  28634,  59727, 268622,
#        188951],
#       dtype='int64', name='userid', length=899)

# %%
ratings= ratings[ratings["userid"].isin(y)]

# %%
ratings.head()
# Out:
#       userid        isbn  rating
# 1456  277427  002542730X      10
# 1457  277427  0026217457       0
# 1458  277427  003008685X       8
# 1459  277427  0030615321       0
# 1460  277427  0060002050       0

# %%
ratings.shape
# Out:
# (526356, 3)

# %%
books1.head(1)
# Out:
#          isbn                title              author  year  \
# 0  0195153448  Classical Mythology  Mark P. O. Morford  2002
#
#                  publisher                                        Image-URL-S  \
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
#
#                                                  img  \
# 0  http://images.amazon.com/images/P/0195153448.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...

# %%
ratings_with_books = ratings.merge(books1, on="isbn")

# %%
ratings_with_books.head(3)
# Out:
#    userid        isbn  rating  \
# 0  277427  002542730X      10
# 1    3363  002542730X       0
# 2   11676  002542730X       6
#
#                                                title             author  year  \
# 0  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 1  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 2  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
#
#                    publisher  \
# 0  John Wiley &amp; Sons Inc
# 1  John Wiley &amp; Sons Inc
# 2  John Wiley &amp; Sons Inc
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/002542730X.0...
# 1  http://images.amazon.com/images/P/002542730X.0...
# 2  http://images.amazon.com/images/P/002542730X.0...
#
#                                                  img  \
# 0  http://images.amazon.com/images/P/002542730X.0...
# 1  http://images.amazon.com/images/P/002542730X.0...
# ...

# %%
rating_books=books.merge(ratings_with_books, on="title")

# %%
print(books.columns)
print(ratings_with_books.columns)
# Out:
# Index(['bookId', 'title', 'series', 'author', 'rating', 'description',
#        'language', 'isbn', 'genres', 'characters', 'bookFormat', 'edition',
#        'pages', 'publisher', 'publishDate', 'firstPublishDate', 'awards',
#        'numRatings', 'ratingsByStars', 'likedPercent', 'setting', 'coverImg',
#        'bbeScore', 'bbeVotes', 'price'],
#       dtype='object')
# Index(['userid', 'isbn', 'rating', 'title', 'author', 'year', 'publisher',
#        'Image-URL-S', 'img', 'Image-URL-L'],
#       dtype='object')

# %%
rating_books.head(3)
# Out:
#                        bookId                  title                 series  \
# 0  2657.To_Kill_a_Mockingbird  To Kill a Mockingbird  To Kill a Mockingbird
# 1  2657.To_Kill_a_Mockingbird  To Kill a Mockingbird  To Kill a Mockingbird
# 2  2657.To_Kill_a_Mockingbird  To Kill a Mockingbird  To Kill a Mockingbird
#
#      author_x  rating_x                                        description  \
# 0  Harper Lee      4.28  The unforgettable novel of a childhood in a sl...
# 1  Harper Lee      4.28  The unforgettable novel of a childhood in a sl...
# 2  Harper Lee      4.28  The unforgettable novel of a childhood in a sl...
#
#   language         isbn_x                                             genres  \
# 0  English  9999999999999  ['Classics', 'Fiction', 'Historical Fiction', ...
# 1  English  9999999999999  ['Classics', 'Fiction', 'Historical Fiction', ...
# 2  English  9999999999999  ['Classics', 'Fiction', 'Historical Fiction', ...
#
# ...

# %%
rating_books.columns
# Out:
# Index(['bookId', 'title', 'series', 'author_x', 'rating_x', 'description',
#        'language', 'isbn_x', 'genres', 'characters', 'bookFormat', 'edition',
#        'pages', 'publisher_x', 'publishDate', 'firstPublishDate', 'awards',
#        'numRatings', 'ratingsByStars', 'likedPercent', 'setting', 'coverImg',
#        'bbeScore', 'bbeVotes', 'price', 'userid', 'isbn_y', 'rating_y',
#        'author_y', 'year', 'publisher_y', 'Image-URL-S', 'img', 'Image-URL-L'],
#       dtype='object')

# %%
books = pd.read_csv('books_1.Best_Books_Ever.csv',sep=";", on_bad_lines="skip", encoding='latin-1')

# %%
books.columns
# Out:
# Index(['bookId,"title","series","author","rating","description","language","isbn","genres","characters","bookFormat","edition","pages","publisher","publishDate","firstPublishDate","awards","numRatings","ratingsByStars","likedPercent","setting","coverImg","bbeScore","bbeVotes","price"'], dtype='object')

# %%
books1.columns
# Out:
# Index(['isbn', 'title', 'author', 'year', 'publisher', 'Image-URL-S', 'img',
#        'Image-URL-L'],
#       dtype='object')

# %% [markdown]
# # Collabrative filtering recommender system

# %%
book_pivot= rating_books.pivot_table(columns= "userid",index="title", values="rating_x")
# Load your CSV file into a DataFrame

# %%
book_pivot
# Out:
# userid                                              254     2276    2766    \
# title
# 'Salem's Lot                                           NaN     NaN     NaN
# ...And Ladies of the Club                              NaN     NaN     NaN
# 1,000 Places to See Before You Die                     NaN     NaN     NaN
# 10 Secrets for Success and Inner Peace                 NaN     NaN     NaN
# 100 Selected Poems                                     NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Zombie                                                 NaN     NaN     NaN
# Zorba the Greek                                        NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# Zoya's Story: An Afghan Woman's Struggle for Fr...     NaN     NaN     NaN
# god bless the gargoyles                                NaN     NaN     NaN
#
# ...

# %%
print(book_pivot)
# Out:
# userid                                              254     2276    2766    \
# title
# 'Salem's Lot                                           NaN     NaN     NaN
# ...And Ladies of the Club                              NaN     NaN     NaN
# 1,000 Places to See Before You Die                     NaN     NaN     NaN
# 10 Secrets for Success and Inner Peace                 NaN     NaN     NaN
# 100 Selected Poems                                     NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Zombie                                                 NaN     NaN     NaN
# Zorba the Greek                                        NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# Zoya's Story: An Afghan Woman's Struggle for Fr...     NaN     NaN     NaN
# god bless the gargoyles                                NaN     NaN     NaN
#
# ...

# %%
rating_books.head(15)
# Out:
#                         bookId                  title                 series  \
# 0   2657.To_Kill_a_Mockingbird  To Kill a Mockingbird  To Kill a Mockingbird
# 1   2657.To_Kill_a_Mockingbird  To Kill a Mockingbird  To Kill a Mockingbird
# 2   2657.To_Kill_a_Mockingbird  To Kill a Mockingbird  To Kill a Mockingbird
# 3   2657.To_Kill_a_Mockingbird  To Kill a Mockingbird  To Kill a Mockingbird
# 4   2657.To_Kill_a_Mockingbird  To Kill a Mockingbird  To Kill a Mockingbird
# 5   2657.To_Kill_a_Mockingbird  To Kill a Mockingbird  To Kill a Mockingbird
# 6   2657.To_Kill_a_Mockingbird  To Kill a Mockingbird  To Kill a Mockingbird
# 7   2657.To_Kill_a_Mockingbird  To Kill a Mockingbird  To Kill a Mockingbird
# 8   2657.To_Kill_a_Mockingbird  To Kill a Mockingbird  To Kill a Mockingbird
# 9   2657.To_Kill_a_Mockingbird  To Kill a Mockingbird  To Kill a Mockingbird
# 10  2657.To_Kill_a_Mockingbird  To Kill a Mockingbird  To Kill a Mockingbird
# ...

# %%
rating_books.shape
# Out:
# (127007, 34)

# %%
unique_books = rating_books.drop_duplicates(subset='title')

# %%
unique_books.shape
# Out:
# (8303, 34)

# %%
unique_books.columns
# Out:
# Index(['bookId', 'title', 'series', 'author_x', 'rating_x', 'description',
#        'language', 'isbn_x', 'genres', 'characters', 'bookFormat', 'edition',
#        'pages', 'publisher_x', 'publishDate', 'firstPublishDate', 'awards',
#        'numRatings', 'ratingsByStars', 'likedPercent', 'setting', 'coverImg',
#        'bbeScore', 'bbeVotes', 'price', 'userid', 'isbn_y', 'rating_y',
#        'author_y', 'year', 'publisher_y', 'Image-URL-S', 'img', 'Image-URL-L'],
#       dtype='object')

# %%
book_pivot
# Out:
# userid                                              254     2276    2766    \
# title
# 'Salem's Lot                                           NaN     NaN     NaN
# ...And Ladies of the Club                              NaN     NaN     NaN
# 1,000 Places to See Before You Die                     NaN     NaN     NaN
# 10 Secrets for Success and Inner Peace                 NaN     NaN     NaN
# 100 Selected Poems                                     NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Zombie                                                 NaN     NaN     NaN
# Zorba the Greek                                        NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# Zoya's Story: An Afghan Woman's Struggle for Fr...     NaN     NaN     NaN
# god bless the gargoyles                                NaN     NaN     NaN
#
# ...

# %%
book_pivot.fillna(0,inplace=True)

# %%
book_pivot
# Out:
# userid                                              254     2276    2766    \
# title
# 'Salem's Lot                                           0.0     0.0     0.0
# ...And Ladies of the Club                              0.0     0.0     0.0
# 1,000 Places to See Before You Die                     0.0     0.0     0.0
# 10 Secrets for Success and Inner Peace                 0.0     0.0     0.0
# 100 Selected Poems                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Zombie                                                 0.0     0.0     0.0
# Zorba the Greek                                        0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# Zoya's Story: An Afghan Woman's Struggle for Fr...     0.0     0.0     0.0
# god bless the gargoyles                                0.0     0.0     0.0
#
# ...

# %%
from scipy.sparse import csr_matrix

# %%
book_sparse = csr_matrix(book_pivot)

# %%
book_sparse
# Out:
# <8303x898 sparse matrix of type '<class 'numpy.float64'>'
# 	with 93813 stored elements in Compressed Sparse Row format>

# %%
from sklearn.neighbors import NearestNeighbors
model = NearestNeighbors(algorithm='brute')

# %%
model.fit(book_sparse)
# Out:
# NearestNeighbors(algorithm='brute')

# %%
distance, suggestion=  model.kneighbors(book_pivot.iloc[237,:].values.reshape(1,-1),n_neighbors=6)

# %%
distance
# Out:
# array([[0.  , 0.04, 0.12, 0.12, 0.13, 0.14]])

# %%
suggestion
# Out:
# array([[ 237,  953, 4326, 4787, 1429, 3086]], dtype=int64)

# %%
for i in range(len(suggestion)):
    print(book_pivot.index[suggestion[i]])
# Out:
# Index(['A Stillness at Appomattox', 'Boy in the Air', 'Power of Silence',
#        'Selected Poetry', 'Dances with Wolves', 'King'],
#       dtype='object', name='title')

# %%
book_pivot.index[3]
# Out:
# '10 Secrets for Success and Inner Peace'

# %%
book_pivot.columns[3]
# Out:
# 2977

# %%
book_name= book_pivot.columns

# %%
import pickle 
pickle.dump(model, open('artifacts/model.pkl','wb'))
pickle.dump(book_name, open('artifacts/book_name.pkl', 'wb'))
pickle.dump(unique_books, open('artifacts/unique_books.pkl', 'wb'))
pickle.dump(book_pivot, open('artifacts/book_pivot.pkl', 'wb'))

# %%
book_pivot.columns
# Out:
# Index([   254,   2276,   2766,   2977,   3363,   3757,   4017,   4385,   6242,
#          6251,
#        ...
#        274004, 274061, 274301, 274308, 274808, 275970, 277427, 277478, 277639,
#        278418],
#       dtype='int64', name='userid', length=898)

# %%
book_pivot.index
# Out:
# Index([''Salem's Lot', '...And Ladies of the Club',
#        '1,000 Places to See Before You Die',
#        '10 Secrets for Success and Inner Peace', '100 Selected Poems',
#        '101 Dalmatians', '13', '1421: The Year China Discovered America',
#        '1876', '1939',
#        ...
#        'Zenzele: A Letter for My Daughter', 'Zero', 'Zero Hour',
#        'Zero at the Bone', 'Zodiac', 'Zombie', 'Zorba the Greek', 'Zoya',
#        'Zoya's Story: An Afghan Woman's Struggle for Freedom',
#        'god bless the gargoyles'],
#       dtype='object', name='title', length=8303)

# %%
unique_books.head(7000)
# Out:
#                                          bookId  \
# 0                    2657.To_Kill_a_Mockingbird
# 186                    1885.Pride_and_Prejudice
# 250                              41865.Twilight
# 274                          170448.Animal_Farm
# 414              11127.The_Chronicles_of_Narnia
# ...                                         ...
# 117224                   370899.The_Dark_Design
# 117225  182465.A_Creed_for_the_Third_Millennium
# 117229                             169587.Frida
# 117233                         20024.The_Maiden
# 117244          156770.The_Return_of_the_Indian
#
#                                    title  \
# 0                  To Kill a Mockingbird
# 186                  Pride and Prejudice
# 250                             Twilight
# 274                          Animal Farm
# 414             The Chronicles of Narnia
# ...                                  ...
# 117224                   The Dark Design
# 117225  A Creed for the Third Millennium
# ...

# %%
distance, suggestion=  model.kneighbors(book_pivot.iloc[250,:].values.reshape(1,-1),n_neighbors=10)

# %%
suggestion
# Out:
# array([[ 250, 5982, 8136, 4815, 5341, 6015, 4714,  125, 1378, 2119]],
#       dtype=int64)

# %%
for i in range(len(suggestion)):
    print(book_pivot.index[suggestion[i]])
# Out:
# Index(['A Tale of Two Cities', 'The Eagle of the Ninth',
#        'Why Men Don't Listen and Women Can't Read Maps: How We're Different and What to Do About It',
#        'Sex and the City', 'Tangerine', 'The English Lady', 'Savage Season',
#        'A Heritage of Shadows', 'Cross Country', 'Five Children and It'],
#       dtype='object', name='title')

# %%
book_pivot.index[2500]
# Out:
# 'Harry Potter and the Prisoner of Azkaban'

# %%
distance, suggestion=  model.kneighbors(book_pivot.iloc[2500,:].values.reshape(1,-1),n_neighbors=10)

# %%
suggestion
# Out:
# array([[2500, 5797,  598,  600, 1289, 6404, 6237, 2479,  309, 3047]],
#       dtype=int64)

# %%
for i in range(len(suggestion)):
    print(book_pivot.index[suggestion[i]])
# Out:
# Index(['Harry Potter and the Prisoner of Azkaban', 'The Complete Works',
#        'Asterix and Cleopatra', 'Asterix in Switzerland', 'Collected Poems',
#        'The Kenneth Williams Diaries', 'The Greek Myths', 'Hangover Square',
#        'Accidental Death of an Anarchist', 'Just William'],
#       dtype='object', name='title')

# %%
book_pivot.index[2501]
# Out:
# "Hart's Hope"

# %%
book_pivot.index[2498]
# Out:
# 'Harry Potter and the Chamber of Secrets'

# %% [markdown]
# # Content Based Recommender system (Author + Genre)

# %%
unique_books = unique_books[['title','author_x','description','genres','setting']]

# %%
unique_books.head()
# Out:
#                         title  \
# 0       To Kill a Mockingbird
# 186       Pride and Prejudice
# 250                  Twilight
# 274               Animal Farm
# 414  The Chronicles of Narnia
#
#                                               author_x  \
# 0                                           Harper Lee
# 186          Jane Austen, Anna Quindlen (Introduction)
# 250                                    Stephenie Meyer
# 274  George Orwell, Russell Baker (Preface), C.M. W...
# 414           C.S. Lewis, Pauline Baynes (Illustrator)
#
#                                            description  \
# 0    The unforgettable novel of a childhood in a sl...
# 186  Alternate cover edition of ISBN 9780679783268S...
# 250  About three things I was absolutely positive.\...
# 274  Librarian's note: There is an Alternate Cover ...
# 414  Journeys to the end of the world, fantastic cr...
#
#                                                 genres  \
# ...

# %%
unique_books.isnull().sum()
# Out:
# title           0
# author_x        0
# description    62
# genres          0
# setting         0
# dtype: int64

# %%
unique_books['description'] = unique_books['description'].astype(str)

# %%
unique_books.dropna(inplace=True)
